# %% [markdown]
# # Recurrent Neural Networks

# %% [markdown]
# ## Univariate Time Series Regression

# %% [markdown]
# This notebook demonstrates how to forecast the S&P 500 index using a Recurrent Neural Network.

# %% [markdown]
# ## Imports & Settings

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %matplotlib inline

from pathlib import Path

import numpy as np
import pandas as pd
import pandas_datareader.data as web
from scipy.stats import spearmanr

from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler

import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
from tensorflow import keras

import matplotlib.pyplot as plt
import seaborn as sns

# %%
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
if gpu_devices:
    print('Using GPU')
    tf.config.experimental.set_memory_growth(gpu_devices[0], True)
else:
    print('Using CPU')
# Out:
# Using CPU

# %%
sns.set_style('whitegrid')
np.random.seed(42)

# %%
results_path = Path('results', 'univariate_time_series')
if not results_path.exists():
    results_path.mkdir(parents=True)

# %% [markdown]
# ## Get Data

# %% [markdown]
# We obtain data for 2010-2018 from the Federal Reserve Bank’s Data Service [FRED](https://fred.stlouisfed.org/) using the [pandas_datareader](https://pandas-datareader.readthedocs.io/) library in introduced in [Chapter 2 on Market and Fundamental Data](../02_market_and_fundamental_data).

# %%
import yfinance as yf
sp500 = yf.download('^GSPC', period='10y', interval='1mo')['Adj Close']
sp500 = pd.DataFrame(sp500)
sp500.columns = ['SP500']
ax = sp500.plot(title='S&P 500', legend=False, figsize=(14, 4), rot=0)
ax.set_xlabel('')
sns.despine();
sp500
# Out:
# [*********************100%***********************]  1 of 1 completed
# Text(0.5, 0, '')
#                   SP500
# Date
# 2011-01-01  1286.119995
# 2011-02-01  1327.219971
# 2011-03-01  1325.829956
# 2011-04-01  1363.609985
# 2011-05-01  1345.199951
# ...                 ...
# 2020-09-01  3363.000000
# 2020-10-01  3269.959961
# 2020-11-01  3621.629883
# 2020-12-01  3732.040039
# 2020-12-30  3732.040039
#
# [121 rows x 1 columns]

# %% [markdown]
# ## Preprocessing

# %%
scaler = MinMaxScaler()

# %%
sp500_scaled = pd.Series(scaler.fit_transform(sp500).squeeze(), index=sp500.index)
sp500_scaled.describe()
# Out:
# count    121.000000
# mean       0.407107
# std        0.249353
# min        0.000000
# 25%        0.192858
# 50%        0.366870
# 75%        0.607670
# max        1.000000
# dtype: float64

# %% [markdown]
# ## Generating recurrent sequences from our time series
#
# Our time series is a sequence of numbers indexed by time:
#
# $$x_{0},x_{1},x_{2},...,x_{T}$$
#
# where $\{x_t\}$ is the numerical value in period $t$ and  $T$ is the total length of the series.
#
# To apply a RNN for regression of classification, we use a sliding window to construct a rolling set of input/output pairs for our model to learn from as animated below.

# %% [markdown]
# We will generate sequences of 63 trading days, approximately three months, and use a single LSTM layer with 20 hidden units to predict the index value one timestep ahead.
# The input to every LSTM layer must have three dimensions, namely:
# - **Samples**: One sequence is one sample. A batch contains one or more samples.
# - **Time Steps**: One time step is one point of observation in the sample.
# - **Features**: One feature is one observation at a time step.
#
# Our S&P 500 sample has 2,264 observations or time steps. We will create overlapping sequences using a window of 63 observations each.
# For a simpler window of size T = 5, we obtain input-output pairs as shown in the following table:

# %% [markdown]
# Generally speaking, for window size S, the relationship takes the form
#
# $$x_t = f( x_{t-1}, x_{t-2}, ..., x_{t-S}) \quad\forall t=S, S+1, ..., T$$
#
# Each of the $T-S$ lagged input sequence or vector is of length S with a corresponding scalar output.

# %% [markdown]
# We can use the function create_univariate_rnn_data() to stack sequences selected using a rolling windows:

# %%
def create_univariate_rnn_data(data, window_size):
    n = len(data)
    y = data[window_size:]
    data = data.values.reshape(-1, 1) # make 2D
    X = np.hstack(tuple([data[i: n-j, :] for i, j in enumerate(range(window_size, 0, -1))]))
    return pd.DataFrame(X, index=y.index), y

# %% [markdown]
# We apply this function to the rescaled stock index for a window_size=63 to obtain a two-dimensional dataset of shape number of samples x number of timesteps:

# %%
window_size = 63

# %%
X, y = create_univariate_rnn_data(sp500_scaled, window_size=window_size)

# %%
X.head()
# Out:
#                   0         1         2         3         4         5   \
# Date
# 2016-04-01  0.059486  0.075290  0.074755  0.089283  0.082203  0.072760
# 2016-05-01  0.075290  0.074755  0.089283  0.082203  0.072760  0.061854
# 2016-06-01  0.074755  0.089283  0.082203  0.072760  0.061854  0.033634
# 2016-07-01  0.089283  0.082203  0.072760  0.061854  0.033634  0.000000
# 2016-08-01  0.082203  0.072760  0.061854  0.033634  0.000000  0.046866
#
#                   6         7         8         9         10        11  \
# Date
# 2016-04-01  0.061854  0.033634  0.000000  0.046866  0.044428  0.048519
# 2016-05-01  0.033634  0.000000  0.046866  0.044428  0.048519  0.069595
# 2016-06-01  0.000000  0.046866  0.044428  0.048519  0.069595  0.090079
# 2016-07-01  0.046866  0.044428  0.048519  0.069595  0.090079  0.106532
# 2016-08-01  0.044428  0.048519  0.069595  0.090079  0.106532  0.102472
#
#                   12        13        14  ...        48        49        50  \
# Date                                      ...
# 2016-04-01  0.069595  0.090079  0.106532  ...  0.332063  0.374172  0.360095
# 2016-05-01  0.090079  0.106532  0.102472  ...  0.374172  0.360095  0.366870
# 2016-06-01  0.106532  0.102472  0.068795  ...  0.360095  0.366870  0.375284
# 2016-07-01  0.102472  0.068795  0.088725  ...  0.366870  0.375284  0.358257
# 2016-08-01  0.068795  0.088725  0.095323  ...  0.375284  0.358257  0.373919
#
#                   51        52        53        54        55        56  \
# Date
# 2016-04-01  0.366870  0.375284  0.358257  0.373919  0.323292  0.303239
# 2016-05-01  0.375284  0.358257  0.373919  0.323292  0.303239  0.364505
# 2016-06-01  0.358257  0.373919  0.323292  0.303239  0.364505  0.364909
# 2016-07-01  0.373919  0.323292  0.303239  0.364505  0.364909  0.350886
# 2016-08-01  0.323292  0.303239  0.364505  0.364909  0.350886  0.311010
#
#                   57        58        59        60        61        62
# Date
# 2016-04-01  0.364505  0.364909  0.350886  0.311010  0.307930  0.356961
# 2016-05-01  0.364909  0.350886  0.311010  0.307930  0.356961  0.359099
# 2016-06-01  0.350886  0.311010  0.307930  0.356961  0.359099  0.371269
# 2016-07-01  0.311010  0.307930  0.356961  0.359099  0.371269  0.372004
# 2016-08-01  0.307930  0.356961  0.359099  0.371269  0.372004  0.400743
#
# [5 rows x 63 columns]

# %%
y.head()
# Out:
# Date
# 2016-04-01    0.359099
# 2016-05-01    0.371269
# 2016-06-01    0.372004
# 2016-07-01    0.400743
# 2016-08-01    0.399724
# dtype: float64

# %%
X.shape
# Out:
# (58, 63)

# %% [markdown]
# ## Train-test split
#
# To respect the time series nature of the data, we set aside the data at the end of the sample as hold-out or test set. More specifically, we'll use the data for 2018.

# %%
ax = sp500_scaled.plot(lw=2, figsize=(14, 4), rot=0)
ax.set_xlabel('')
sns.despine();
# Out:
# Text(0.5, 0, '')

# %%
X_train = X[:'2018'].values.reshape(-1, window_size, 1)
y_train = y[:'2018']

# keep the last year for testing
X_test = X['2020'].values.reshape(-1, window_size, 1)
y_test = y['2020']

# %%
n_obs, window_size, n_features = X_train.shape

# %%
y_train.shape
# Out:
# (33,)

# %% [markdown]
# ## Keras LSTM Layer

# %% [markdown]
# Keras has several built-in RNN layers with various configuration options described in detail in the [documentation](https://keras.io/layers/recurrent/).

# %% [markdown]
# ```
# LSTM(units,
#      activation='tanh',
#      recurrent_activation='hard_sigmoid',
#      use_bias=True,
#      kernel_initializer='glorot_uniform',
#      recurrent_initializer='orthogonal',
#      bias_initializer='zeros',
#      unit_forget_bias=True,
#      kernel_regularizer=None,
#      recurrent_regularizer=None,
#      bias_regularizer=None,
#      activity_regularizer=None,
#      kernel_constraint=None,
#      recurrent_constraint=None,
#      bias_constraint=None,
#      dropout=0.0,
#      recurrent_dropout=0.0,
#      implementation=1,
#      return_sequences=False,
#      return_state=False,
#      go_backwards=False,
#      stateful=False,
#      unroll=False)
#  ```

# %% [markdown]
# ##  Define the Model Architecture
#
# Having created input/output pairs out of our time series and cut this into training/testing sets, we can now begin setting up our RNN.  We use Keras to quickly build a two hidden layer RNN of the following specifications
#
# - layer 1 uses an LSTM module with 20 hidden units (note here the input_shape = (window_size,1))
# - layer 2 uses a fully connected module with one unit
# - the 'mean_squared_error' loss should be used (remember: we are performing regression here)
#
# This can be constructed using just a few lines - see e.g., the [general Keras documentation](https://keras.io/getting-started/sequential-model-guide/) and the [LSTM documentation in particular](https://keras.io/layers/recurrent/) for examples of how to quickly use Keras to build neural network models.  Make sure you are initializing your optimizer given the [keras-recommended approach for RNNs](https://keras.io/optimizers/)

# %%
rnn = Sequential([
    LSTM(units=10, 
         input_shape=(window_size, n_features), name='LSTM'),
    Dense(1, name='Output')
])

# %% [markdown]
# The summary shows that the model has 1,781 parameters:

# %%
rnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM (LSTM)                  (None, 10)                480
# _________________________________________________________________
# Output (Dense)               (None, 1)                 11
# =================================================================
# Total params: 491
# Trainable params: 491
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train the Model

# %% [markdown]
# We train the model using the RMSProp optimizer recommended for RNN with default settings and compile the model with mean squared error for this regression problem:

# %%
optimizer = keras.optimizers.RMSprop(lr=0.001,
                                     rho=0.9,
                                     epsilon=1e-08,
                                     decay=0.0)

# %%
rnn.compile(loss='mean_squared_error', 
            optimizer=optimizer)

# %% [markdown]
# We define an EarlyStopping callback and train the model for up to 100 episodes.

# %%
rnn_path = (results_path / 'rnn.h5').as_posix()
checkpointer = ModelCheckpoint(filepath=rnn_path,
                               verbose=1,
                               monitor='val_loss',
                               save_best_only=True)

# %%
early_stopping = EarlyStopping(monitor='val_loss', 
                              patience=20,
                              restore_best_weights=True)

# %%
lstm_training = rnn.fit(X_train,
                        y_train,
                        epochs=150,
                        batch_size=20,
                        shuffle=True,
                        validation_data=(X_test, y_test),
                        callbacks=[early_stopping, checkpointer],
                        verbose=1)
# Out:
# 0018
# Epoch 00020: val_loss did not improve from 0.00395
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0020 - val_loss: 0.0058
# Epoch 21/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0022
# Epoch 00021: val_loss did not improve from 0.00395
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0018 - val_loss: 0.0045
# Epoch 22/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0016
# Epoch 00022: val_loss did not improve from 0.00395
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0018 - val_loss: 0.0041
# Epoch 23/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0014
# Epoch 00023: val_loss did not improve from 0.00395
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0018 - val_loss: 0.0046
# Epoch 24/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0021
# Epoch 00024: val_loss improved from 0.00395 to 0.00384, saving model to results/univariate_time_series/rnn.h5
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0018 - val_loss: 0.0038
# Epoch 25/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0014
# Epoch 00025: val_loss did not improve from 0.00384
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0018 - val_loss: 0.0057
# Epoch 26/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0021
# Epoch 00026: val_loss improved from 0.00384 to 0.00317, saving model to results/univariate_time_series/rnn.h5
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0018 - val_loss: 0.0032
# Epoch 27/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0023
# Epoch 00027: val_loss did not improve from 0.00317
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0018 - val_loss: 0.0036
# Epoch 28/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0018
# Epoch 00028: val_loss improved from 0.00317 to 0.00251, saving model to results/univariate_time_series/rnn.h5
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0019 - val_loss: 0.0025
# Epoch 29/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0026
# Epoch 00029: val_loss did not improve from 0.00251
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0018 - val_loss: 0.0035
# Epoch 30/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0016
# Epoch 00030: val_loss did not improve from 0.00251
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0017 - val_loss: 0.0043
# Epoch 31/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0019
# Epoch 00031: val_loss did not improve from 0.00251
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0020 - val_loss: 0.0065
# Epoch 32/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0012
# Epoch 00032: val_loss improved from 0.00251 to 0.00251, saving model to results/univariate_time_series/rnn.h5
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0018 - val_loss: 0.0025
# Epoch 33/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0011
# Epoch 00033: val_loss improved from 0.00251 to 0.00222, saving model to results/univariate_time_series/rnn.h5
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 34/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0022
# Epoch 00034: val_loss did not improve from 0.00222
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0017 - val_loss: 0.0036
# Epoch 35/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0016
# Epoch 00035: val_loss did not improve from 0.00222
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0017 - val_loss: 0.0049
# Epoch 36/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0019
# Epoch 00036: val_loss did not improve from 0.00222
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0018 - val_loss: 0.0045
# Epoch 37/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0017
# Epoch 00037: val_loss did not improve from 0.00222
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0017 - val_loss: 0.0039
# Epoch 38/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0019
# Epoch 00038: val_loss did not improve from 0.00222
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0018 - val_loss: 0.0053
# Epoch 39/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0015
# Epoch 00039: val_loss did not improve from 0.00222
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0017 - val_loss: 0.0028
# Epoch 40/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0019
# Epoch 00040: val_loss did not improve from 0.00222
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0015 - val_loss: 0.0031
# Epoch 41/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0017
# Epoch 00041: val_loss improved from 0.00222 to 0.00201, saving model to results/univariate_time_series/rnn.h5
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0016 - val_loss: 0.0020
# Epoch 42/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0017
# Epoch 00042: val_loss did not improve from 0.00201
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0017 - val_loss: 0.0026
# Epoch 43/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0016
# Epoch 00043: val_loss improved from 0.00201 to 0.00191, saving model to results/univariate_time_series/rnn.h5
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 44/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0022
# Epoch 00044: val_loss improved from 0.00191 to 0.00191, saving model to results/univariate_time_series/rnn.h5
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 45/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0022
# Epoch 00045: val_loss did not improve from 0.00191
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0015 - val_loss: 0.0036
# Epoch 46/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0018
# Epoch 00046: val_loss did not improve from 0.00191
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0015 - val_loss: 0.0026
# Epoch 47/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0010
# Epoch 00047: val_loss did not improve from 0.00191
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0015 - val_loss: 0.0045
# Epoch 48/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0015
# Epoch 00048: val_loss did not improve from 0.00191
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0015 - val_loss: 0.0019
# Epoch 49/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0011
# Epoch 00049: val_loss did not improve from 0.00191
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0015 - val_loss: 0.0048
# Epoch 50/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0024
# Epoch 00050: val_loss did not improve from 0.00191
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0023 - val_loss: 0.0043
# Epoch 51/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0016
# Epoch 00051: val_loss did not improve from 0.00191
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0020 - val_loss: 0.0040
# Epoch 52/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0023
# Epoch 00052: val_loss did not improve from 0.00191
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 53/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0016
# Epoch 00053: val_loss did not improve from 0.00191
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 54/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0014
# Epoch 00054: val_loss improved from 0.00191 to 0.00161, saving model to results/univariate_time_series/rnn.h5
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 55/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0023
# Epoch 00055: val_loss did not improve from 0.00161
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 56/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0011
# Epoch 00056: val_loss did not improve from 0.00161
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 57/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0018
# Epoch 00057: val_loss did not improve from 0.00161
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0014 - val_loss: 0.0024
# Epoch 58/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0018
# Epoch 00058: val_loss did not improve from 0.00161
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0014 - val_loss: 0.0027
# Epoch 59/150
# 1/2 [==============>...............] - ETA: 0s - loss: 8.0934e-04
# Epoch 00059: val_loss did not improve from 0.00161
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0015 - val_loss: 0.0033
# Epoch 60/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0016
# Epoch 00060: val_loss improved from 0.00161 to 0.00159, saving model to results/univariate_time_series/rnn.h5
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 61/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0021
# Epoch 00061: val_loss did not improve from 0.00159
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 62/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0020
# Epoch 00062: val_loss did not improve from 0.00159
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 63/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0011
# Epoch 00063: val_loss did not improve from 0.00159
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0014 - val_loss: 0.0042
# Epoch 64/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0025
# Epoch 00064: val_loss did not improve from 0.00159
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0019 - val_loss: 0.0030
# Epoch 65/150
# 1/2 [==============>...............] - ETA: 0s - loss: 9.9427e-04
# Epoch 00065: val_loss did not improve from 0.00159
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0015 - val_loss: 0.0028
# Epoch 66/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0017
# Epoch 00066: val_loss improved from 0.00159 to 0.00159, saving model to results/univariate_time_series/rnn.h5
# 2/2 [==============================] - 0s 28ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 67/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0018
# Epoch 00067: val_loss did not improve from 0.00159
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 68/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0013
# Epoch 00068: val_loss did not improve from 0.00159
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0014 - val_loss: 0.0038
# Epoch 69/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0022
# Epoch 00069: val_loss did not improve from 0.00159
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0018 - val_loss: 0.0029
# Epoch 70/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0013
# Epoch 00070: val_loss improved from 0.00159 to 0.00150, saving model to results/univariate_time_series/rnn.h5
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 71/150
# 1/2 [==============>...............] - ETA: 0s - loss: 9.9044e-04
# Epoch 00071: val_loss did not improve from 0.00150
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0014 - val_loss: 0.0046
# Epoch 72/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0026
# Epoch 00072: val_loss did not improve from 0.00150
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0019 - val_loss: 0.0023
# Epoch 73/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0019
# Epoch 00073: val_loss did not improve from 0.00150
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0014 - val_loss: 0.0021
# Epoch 74/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0014
# Epoch 00074: val_loss improved from 0.00150 to 0.00150, saving model to results/univariate_time_series/rnn.h5
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 75/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0017
# Epoch 00075: val_loss did not improve from 0.00150
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0015 - val_loss: 0.0021
# Epoch 76/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0016
# Epoch 00076: val_loss did not improve from 0.00150
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 77/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0021
# Epoch 00077: val_loss did not improve from 0.00150
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 78/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0017
# Epoch 00078: val_loss did not improve from 0.00150
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0015 - val_loss: 0.0019
# Epoch 79/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0016
# Epoch 00079: val_loss did not improve from 0.00150
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0014 - val_loss: 0.0034
# Epoch 80/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0013
# Epoch 00080: val_loss did not improve from 0.00150
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 81/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0019
# Epoch 00081: val_loss did not improve from 0.00150
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0014 - val_loss: 0.0023
# Epoch 82/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0018
# Epoch 00082: val_loss improved from 0.00150 to 0.00148, saving model to results/univariate_time_series/rnn.h5
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 83/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0015
# Epoch 00083: val_loss did not improve from 0.00148
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 84/150
# 1/2 [==============>...............] - ETA: 0s - loss: 7.7710e-04
# Epoch 00084: val_loss did not improve from 0.00148
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0014 - val_loss: 0.0031
# Epoch 85/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0014
# Epoch 00085: val_loss did not improve from 0.00148
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0018 - val_loss: 0.0035
# Epoch 86/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0020
# Epoch 00086: val_loss did not improve from 0.00148
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 87/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0011
# Epoch 00087: val_loss did not improve from 0.00148
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0014 - val_loss: 0.0027
# Epoch 88/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0016
# Epoch 00088: val_loss improved from 0.00148 to 0.00147, saving model to results/univariate_time_series/rnn.h5
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 89/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0018
# Epoch 00089: val_loss improved from 0.00147 to 0.00147, saving model to results/univariate_time_series/rnn.h5
# 2/2 [==============================] - 0s 29ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 90/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0019
# Epoch 00090: val_loss did not improve from 0.00147
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 91/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0014
# Epoch 00091: val_loss did not improve from 0.00147
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 92/150
# 1/2 [==============>...............] - ETA: 0s - loss: 7.1078e-04
# Epoch 00092: val_loss did not improve from 0.00147
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 93/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0020
# Epoch 00093: val_loss did not improve from 0.00147
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 94/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0016
# Epoch 00094: val_loss did not improve from 0.00147
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 95/150
# 1/2 [==============>...............] - ETA: 0s - loss: 9.9182e-04
# Epoch 00095: val_loss did not improve from 0.00147
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0014 - val_loss: 0.0031
# Epoch 96/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0014
# Epoch 00096: val_loss did not improve from 0.00147
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 97/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0013
# Epoch 00097: val_loss did not improve from 0.00147
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 98/150
# 1/2 [==============>...............] - ETA: 0s - loss: 9.0794e-04
# Epoch 00098: val_loss did not improve from 0.00147
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0013 - val_loss: 0.0030
# Epoch 99/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0022
# Epoch 00099: val_loss did not improve from 0.00147
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0015 - val_loss: 0.0019
# Epoch 100/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0018
# Epoch 00100: val_loss did not improve from 0.00147
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 101/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0023
# Epoch 00101: val_loss did not improve from 0.00147
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 102/150
# 1/2 [==============>...............] - ETA: 0s - loss: 7.4659e-04
# Epoch 00102: val_loss did not improve from 0.00147
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0014 - val_loss: 0.0022
# Epoch 103/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0013
# Epoch 00103: val_loss did not improve from 0.00147
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0017 - val_loss: 0.0035
# Epoch 104/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0016
# Epoch 00104: val_loss did not improve from 0.00147
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 105/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0010
# Epoch 00105: val_loss did not improve from 0.00147
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0014 - val_loss: 0.0030
# Epoch 106/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0017
# Epoch 00106: val_loss did not improve from 0.00147
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 107/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0019
# Epoch 00107: val_loss did not improve from 0.00147
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0013 - val_loss: 0.0023
# Epoch 108/150
# 2/2 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 00108: val_loss did not improve from 0.00147
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0014 - val_loss: 0.0024
# Epoch 109/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0016
# Epoch 00109: val_loss did not improve from 0.00147
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0013 - val_loss: 0.0015

# %% [markdown]
# Training stops after 51 epochs; the `early_stopping` callback restores the weights for the best model (after 41 epochs)

# %% [markdown]
# ## Evaluate model performance

# %%
fig, ax = plt.subplots(figsize=(12, 4))

loss_history = pd.DataFrame(lstm_training.history).pow(.5)
loss_history.index += 1
best_rmse = loss_history.val_loss.min()

best_epoch = loss_history.val_loss.idxmin()

title = f'5-Epoch Rolling RMSE (Best Validation RMSE: {best_rmse:.4%})'
loss_history.columns=['Training RMSE', 'Validation RMSE']
loss_history.rolling(5).mean().plot(logy=True, lw=2, title=title, ax=ax)

ax.axvline(best_epoch, ls='--', lw=1, c='k')

sns.despine()
fig.tight_layout()
fig.savefig(results_path / 'rnn_sp500_error', dpi=300);

# %%
train_rmse_scaled = np.sqrt(rnn.evaluate(X_train, y_train, verbose=0))
test_rmse_scaled = np.sqrt(rnn.evaluate(X_test, y_test, verbose=0))
print(f'Train RMSE: {train_rmse_scaled:.4f} | Test RMSE: {test_rmse_scaled:.4f}')
# Out:
# Train RMSE: 0.0404 | Test RMSE: 0.0383

# %%
train_predict_scaled = rnn.predict(X_train)
test_predict_scaled = rnn.predict(X_test)

# %%
train_ic = spearmanr(y_train, train_predict_scaled)[0]
test_ic = spearmanr(y_test, test_predict_scaled)[0]
print(f'Train IC: {train_ic:.4f} | Test IC: {test_ic:.4f}')
# Out:
# Train IC: 0.9295 | Test IC: 0.8671

# %% [markdown]
# ### Rescale predictions

# %%
train_predict = pd.Series(scaler.inverse_transform(train_predict_scaled).squeeze(), index=y_train.index)
test_predict = (pd.Series(scaler.inverse_transform(test_predict_scaled).squeeze(), index=y_test.index))

# %%
y_train_rescaled = scaler.inverse_transform(y_train.to_frame()).squeeze()
y_test_rescaled = scaler.inverse_transform(y_test.to_frame()).squeeze()

# %%
train_rmse = np.sqrt(mean_squared_error(train_predict, y_train_rescaled))
test_rmse = np.sqrt(mean_squared_error(test_predict, y_test_rescaled))
f'Train RMSE: {train_rmse:.2f} | Test RMSE: {test_rmse:.2f}'
# Out:
# 'Train RMSE: 104.94 | Test RMSE: 99.63'

# %%
sp500['Train Predictions'] = train_predict
sp500['Test Predictions'] = test_predict
sp500 = sp500.join(train_predict.to_frame('predictions').assign(data='Train')
                        .append(test_predict.to_frame('predictions').assign(data='Test')))

# %% [markdown]
# ### Plot Results

# %%
fig=plt.figure(figsize=(14,7))
ax1 = plt.subplot(221)

sp500.loc['2015':, 'SP500'].plot(lw=4, ax=ax1, c='k')
sp500.loc['2015':, ['Test Predictions', 'Train Predictions']].plot(lw=1, ax=ax1, ls='--')
ax1.set_title('In- and Out-of-sample Predictions')


with sns.axes_style("white"):
    ax3 = plt.subplot(223)
    sns.scatterplot(x='SP500', y='predictions', data=sp500, hue='data', ax=ax3)
    ax3.text(x=.02, y=.95, s=f'Test IC ={test_ic:.2%}', transform=ax3.transAxes)
    ax3.text(x=.02, y=.87, s=f'Train IC={train_ic:.2%}', transform=ax3.transAxes)
    ax3.set_title('Correlation')
    ax3.legend(loc='lower right')
    
    ax2 = plt.subplot(222)
    ax4 = plt.subplot(224, sharex = ax2, sharey=ax2)
    sns.distplot(train_predict.squeeze()- y_train_rescaled, ax=ax2)
    ax2.set_title('Train Error')
    ax2.text(x=.03, y=.92, s=f'Train RMSE ={train_rmse:.4f}', transform=ax2.transAxes)
    sns.distplot(test_predict.squeeze()-y_test_rescaled, ax=ax4)
    ax4.set_title('Test Error')
    ax4.text(x=.03, y=.92, s=f'Test RMSE ={test_rmse:.4f}', transform=ax4.transAxes)

sns.despine()
fig.tight_layout()
fig.savefig(results_path / 'rnn_sp500_regression', dpi=300);
