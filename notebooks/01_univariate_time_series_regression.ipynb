# %% [markdown]
# # Recurrent Neural Networks

# %% [markdown]
# ## Univariate Time Series Regression

# %% [markdown]
# This notebook demonstrates how to forecast the S&P 500 index using a Recurrent Neural Network.

# %% [markdown]
# ## Imports & Settings

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %matplotlib inline

from pathlib import Path

import numpy as np
import pandas as pd
import pandas_datareader.data as web
from scipy.stats import spearmanr

from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler

import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
from tensorflow import keras

import matplotlib.pyplot as plt
import seaborn as sns

# %%
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
if gpu_devices:
    print('Using GPU')
    tf.config.experimental.set_memory_growth(gpu_devices[0], True)
else:
    print('Using CPU')
# Out:
# Using CPU

# %%
sns.set_style('whitegrid')
np.random.seed(42)

# %%
results_path = Path('results', 'univariate_time_series')
if not results_path.exists():
    results_path.mkdir(parents=True)

# %% [markdown]
# ## Get Data

# %% [markdown]
# We obtain data for 2010-2018 from the Federal Reserve Bank’s Data Service [FRED](https://fred.stlouisfed.org/) using the [pandas_datareader](https://pandas-datareader.readthedocs.io/) library in introduced in [Chapter 2 on Market and Fundamental Data](../02_market_and_fundamental_data).

# %%
import yfinance as yf
sp500 = yf.download('^GSPC', startr='2010-01-01', end='2018-01-01', interval='1mo')['Adj Close']
sp = yf.download('^GSPC', startr='2010-01-01', end='2020-01-01', interval='1mo')['Adj Close']
sp500 = pd.DataFrame(sp500)
sp500.columns = ['SP500']
ax = sp500.plot(title='S&P 500', legend=False, figsize=(14, 4), rot=0)
ax.set_xlabel('')
sns.despine();
sp500
# Out:
# [*********************100%***********************]  1 of 1 completed
# Text(0.5, 0, '')
#                   SP500
# Date
# 2011-02-01  1327.219971
# 2011-03-01  1325.829956
# 2011-04-01  1363.609985
# 2011-05-01  1345.199951
# 2011-06-01  1320.640015
# ...                 ...
# 2020-10-01  3269.959961
# 2020-11-01  3621.629883
# 2020-12-01  3756.070068
# 2021-01-01  3803.790039
# 2021-01-07  3803.790039
#
# [121 rows x 1 columns]

# %% [markdown]
# ## Preprocessing

# %%
scaler = MinMaxScaler()

# %%
sp500_scaled = pd.Series(scaler.fit_transform(sp500).squeeze(), index=sp500.index)
sp500_scaled.describe()
# Out:
# count    121.000000
# mean       0.404259
# std        0.247494
# min        0.000000
# 25%        0.205858
# 50%        0.361301
# 75%        0.592137
# max        1.000000
# dtype: float64

# %% [markdown]
# ## Generating recurrent sequences from our time series
#
# Our time series is a sequence of numbers indexed by time:
#
# $$x_{0},x_{1},x_{2},...,x_{T}$$
#
# where $\{x_t\}$ is the numerical value in period $t$ and  $T$ is the total length of the series.
#
# To apply a RNN for regression of classification, we use a sliding window to construct a rolling set of input/output pairs for our model to learn from as animated below.

# %% [markdown]
# We will generate sequences of 63 trading days, approximately three months, and use a single LSTM layer with 20 hidden units to predict the index value one timestep ahead.
# The input to every LSTM layer must have three dimensions, namely:
# - **Samples**: One sequence is one sample. A batch contains one or more samples.
# - **Time Steps**: One time step is one point of observation in the sample.
# - **Features**: One feature is one observation at a time step.
#
# Our S&P 500 sample has 2,264 observations or time steps. We will create overlapping sequences using a window of 63 observations each.
# For a simpler window of size T = 5, we obtain input-output pairs as shown in the following table:

# %% [markdown]
# Generally speaking, for window size S, the relationship takes the form
#
# $$x_t = f( x_{t-1}, x_{t-2}, ..., x_{t-S}) \quad\forall t=S, S+1, ..., T$$
#
# Each of the $T-S$ lagged input sequence or vector is of length S with a corresponding scalar output.

# %% [markdown]
# We can use the function create_univariate_rnn_data() to stack sequences selected using a rolling windows:

# %%
def create_univariate_rnn_data(data, window_size):
    n = len(data)
    y = data[window_size:]
    data = data.values.reshape(-1, 1) # make 2D
    X = np.hstack(tuple([data[i: n-j, :] for i, j in enumerate(range(window_size, 0, -1))]))
    return pd.DataFrame(X, index=y.index), y

# %% [markdown]
# We apply this function to the rescaled stock index for a window_size=63 to obtain a two-dimensional dataset of shape number of samples x number of timesteps:

# %%
window_size = 63

# %%
X, y = create_univariate_rnn_data(sp500_scaled, window_size=window_size)

# %%
X.head()
# Out:
#                   0         1         2         3         4         5   \
# Date
# 2016-05-01  0.073268  0.072748  0.086885  0.079996  0.070806  0.060194
# 2016-06-01  0.072748  0.086885  0.079996  0.070806  0.060194  0.032731
# 2016-07-01  0.086885  0.079996  0.070806  0.060194  0.032731  0.000000
# 2016-08-01  0.079996  0.070806  0.060194  0.032731  0.000000  0.045607
# 2016-09-01  0.070806  0.060194  0.032731  0.000000  0.045607  0.043235
#
#                   6         7         8         9         10        11  \
# Date
# 2016-05-01  0.032731  0.000000  0.045607  0.043235  0.047216  0.067726
# 2016-06-01  0.000000  0.045607  0.043235  0.047216  0.067726  0.087660
# 2016-07-01  0.045607  0.043235  0.047216  0.067726  0.087660  0.103672
# 2016-08-01  0.043235  0.047216  0.067726  0.087660  0.103672  0.099720
# 2016-09-01  0.047216  0.067726  0.087660  0.103672  0.099720  0.066948
#
#                   12        13        14  ...        48        49        50  \
# Date                                      ...
# 2016-05-01  0.087660  0.103672  0.099720  ...  0.364126  0.350427  0.357020
# 2016-06-01  0.103672  0.099720  0.066948  ...  0.350427  0.357020  0.365208
# 2016-07-01  0.099720  0.066948  0.086343  ...  0.357020  0.365208  0.348638
# 2016-08-01  0.066948  0.086343  0.092764  ...  0.365208  0.348638  0.363879
# 2016-09-01  0.086343  0.092764  0.102965  ...  0.348638  0.363879  0.314612
#
#                   51        52        53        54        55        56  \
# Date
# 2016-05-01  0.365208  0.348638  0.363879  0.314612  0.295098  0.354719
# 2016-06-01  0.348638  0.363879  0.314612  0.295098  0.354719  0.355112
# 2016-07-01  0.363879  0.314612  0.295098  0.354719  0.355112  0.341465
# 2016-08-01  0.314612  0.295098  0.354719  0.355112  0.341465  0.302660
# 2016-09-01  0.295098  0.354719  0.355112  0.341465  0.302660  0.299663
#
#                   57        58        59        60        61        62
# Date
# 2016-05-01  0.355112  0.341465  0.302660  0.299663  0.347377  0.349458
# 2016-06-01  0.341465  0.302660  0.299663  0.347377  0.349458  0.361301
# 2016-07-01  0.302660  0.299663  0.347377  0.349458  0.361301  0.362016
# 2016-08-01  0.299663  0.347377  0.349458  0.361301  0.362016  0.389983
# 2016-09-01  0.347377  0.349458  0.361301  0.362016  0.389983  0.388992
#
# [5 rows x 63 columns]

# %%
y.head()
# Out:
# Date
# 2016-05-01    0.361301
# 2016-06-01    0.362016
# 2016-07-01    0.389983
# 2016-08-01    0.388992
# 2016-09-01    0.387989
# dtype: float64

# %%
X.shape
# Out:
# (58, 63)

# %% [markdown]
# ## Train-test split
#
# To respect the time series nature of the data, we set aside the data at the end of the sample as hold-out or test set. More specifically, we'll use the data for 2018.

# %%
ax = sp500_scaled.plot(lw=2, figsize=(14, 4), rot=0)
ax.set_xlabel('')
sns.despine();

# %%
X_train = X[:'2018'].values.reshape(-1, window_size, 1)
y_train = y[:'2018']

# keep the last year for testing
X_test = X['2020'].values.reshape(-1, window_size, 1)
y_test = y['2020']

# %%
n_obs, window_size, n_features = X_train.shape

# %%
y_train.shape
# Out:
# (32,)

# %% [markdown]
# ## Keras LSTM Layer

# %% [markdown]
# Keras has several built-in RNN layers with various configuration options described in detail in the [documentation](https://keras.io/layers/recurrent/).

# %% [markdown]
# ```
# LSTM(units,
#      activation='tanh',
#      recurrent_activation='hard_sigmoid',
#      use_bias=True,
#      kernel_initializer='glorot_uniform',
#      recurrent_initializer='orthogonal',
#      bias_initializer='zeros',
#      unit_forget_bias=True,
#      kernel_regularizer=None,
#      recurrent_regularizer=None,
#      bias_regularizer=None,
#      activity_regularizer=None,
#      kernel_constraint=None,
#      recurrent_constraint=None,
#      bias_constraint=None,
#      dropout=0.0,
#      recurrent_dropout=0.0,
#      implementation=1,
#      return_sequences=False,
#      return_state=False,
#      go_backwards=False,
#      stateful=False,
#      unroll=False)
#  ```

# %% [markdown]
# ##  Define the Model Architecture
#
# Having created input/output pairs out of our time series and cut this into training/testing sets, we can now begin setting up our RNN.  We use Keras to quickly build a two hidden layer RNN of the following specifications
#
# - layer 1 uses an LSTM module with 20 hidden units (note here the input_shape = (window_size,1))
# - layer 2 uses a fully connected module with one unit
# - the 'mean_squared_error' loss should be used (remember: we are performing regression here)
#
# This can be constructed using just a few lines - see e.g., the [general Keras documentation](https://keras.io/getting-started/sequential-model-guide/) and the [LSTM documentation in particular](https://keras.io/layers/recurrent/) for examples of how to quickly use Keras to build neural network models.  Make sure you are initializing your optimizer given the [keras-recommended approach for RNNs](https://keras.io/optimizers/)

# %%
rnn = Sequential([
    LSTM(units=10, 
         input_shape=(window_size, n_features), name='LSTM'),
    Dense(1, name='Output')
])

# %% [markdown]
# The summary shows that the model has 1,781 parameters:

# %%
rnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM (LSTM)                  (None, 10)                480
# _________________________________________________________________
# Output (Dense)               (None, 1)                 11
# =================================================================
# Total params: 491
# Trainable params: 491
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train the Model

# %% [markdown]
# We train the model using the RMSProp optimizer recommended for RNN with default settings and compile the model with mean squared error for this regression problem:

# %%
optimizer = keras.optimizers.RMSprop(lr=0.001,
                                     rho=0.9,
                                     epsilon=1e-08,
                                     decay=0.0)

# %%
rnn.compile(loss='mean_squared_error', 
            optimizer=optimizer)

# %% [markdown]
# We define an EarlyStopping callback and train the model for up to 100 episodes.

# %%
rnn_path = (results_path / 'rnn.h5').as_posix()
checkpointer = ModelCheckpoint(filepath=rnn_path,
                               verbose=1,
                               monitor='val_loss',
                               save_best_only=True)

# %%
early_stopping = EarlyStopping(monitor='val_loss', 
                              patience=20,
                              restore_best_weights=True)

# %%
lstm_training = rnn.fit(X_train,
                        y_train,
                        epochs=50,
                        batch_size=10,
                        shuffle=True,
                        validation_data=(X_test, y_test),
                        callbacks=[early_stopping, checkpointer],
                        verbose=1)
# Out:
# Epoch 1/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1921
# Epoch 00001: val_loss improved from inf to 0.38480, saving model to results/univariate_time_series/rnn.h5
# 4/4 [==============================] - 1s 159ms/step - loss: 0.1921 - val_loss: 0.3848
# Epoch 2/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1436
# Epoch 00002: val_loss improved from 0.38480 to 0.31624, saving model to results/univariate_time_series/rnn.h5
# 4/4 [==============================] - 0s 25ms/step - loss: 0.1436 - val_loss: 0.3162
# Epoch 3/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1117
# Epoch 00003: val_loss improved from 0.31624 to 0.25137, saving model to results/univariate_time_series/rnn.h5
# 4/4 [==============================] - 0s 27ms/step - loss: 0.1117 - val_loss: 0.2514
# Epoch 4/50
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0910
# Epoch 00004: val_loss improved from 0.25137 to 0.19220, saving model to results/univariate_time_series/rnn.h5
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0826 - val_loss: 0.1922
# Epoch 5/50
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0618
# Epoch 00005: val_loss improved from 0.19220 to 0.13717, saving model to results/univariate_time_series/rnn.h5
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0569 - val_loss: 0.1372
# Epoch 6/50
# 4/4 [==============================] - ETA: 0s - loss: 0.0348
# Epoch 00006: val_loss improved from 0.13717 to 0.09793, saving model to results/univariate_time_series/rnn.h5
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0348 - val_loss: 0.0979
# Epoch 7/50
# 4/4 [==============================] - ETA: 0s - loss: 0.0197
# Epoch 00007: val_loss improved from 0.09793 to 0.05966, saving model to results/univariate_time_series/rnn.h5
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0197 - val_loss: 0.0597
# Epoch 8/50
# 3/4 [=====================>........] - ETA: 0s - loss: 0.0080
# Epoch 00008: val_loss improved from 0.05966 to 0.03936, saving model to results/univariate_time_series/rnn.h5
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0079 - val_loss: 0.0394
# Epoch 9/50
# 4/4 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 00009: val_loss improved from 0.03936 to 0.03284, saving model to results/univariate_time_series/rnn.h5
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0035 - val_loss: 0.0328
# Epoch 10/50
# 4/4 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 00010: val_loss improved from 0.03284 to 0.03129, saving model to results/univariate_time_series/rnn.h5
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0028 - val_loss: 0.0313
# Epoch 11/50
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0036
# Epoch 00011: val_loss improved from 0.03129 to 0.02652, saving model to results/univariate_time_series/rnn.h5
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0026 - val_loss: 0.0265
# Epoch 12/50
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0012
# Epoch 00012: val_loss improved from 0.02652 to 0.02468, saving model to results/univariate_time_series/rnn.h5
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0024 - val_loss: 0.0247
# Epoch 13/50
# 4/4 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 00013: val_loss did not improve from 0.02468
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0026 - val_loss: 0.0301
# Epoch 14/50
# 4/4 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 00014: val_loss did not improve from 0.02468
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0024 - val_loss: 0.0260
# Epoch 15/50
# 4/4 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 00015: val_loss improved from 0.02468 to 0.02339, saving model to results/univariate_time_series/rnn.h5
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0025 - val_loss: 0.0234
# Epoch 16/50
# 4/4 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 00016: val_loss did not improve from 0.02339
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0024 - val_loss: 0.0255
# Epoch 17/50
# 4/4 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 00017: val_loss improved from 0.02339 to 0.02062, saving model to results/univariate_time_series/rnn.h5
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0022 - val_loss: 0.0206
# Epoch 18/50
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0017
# Epoch 00018: val_loss did not improve from 0.02062
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0025 - val_loss: 0.0219
# Epoch 19/50
# 4/4 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 00019: val_loss improved from 0.02062 to 0.01944, saving model to results/univariate_time_series/rnn.h5
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0022 - val_loss: 0.0194
# Epoch 20/50
# 4/4 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 00020: val_loss improved from 0.01944 to 0.01444, saving model to results/univariate_time_series/rnn.h5
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0023 - val_loss: 0.0144
# Epoch 21/50
# 4/4 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 00021: val_loss did not improve from 0.01444
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0028 - val_loss: 0.0192
# Epoch 22/50
# 4/4 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 00022: val_loss did not improve from 0.01444
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0024 - val_loss: 0.0207
# Epoch 23/50
# 4/4 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 00023: val_loss did not improve from 0.01444
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0020 - val_loss: 0.0234
# Epoch 24/50
# 4/4 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 00024: val_loss did not improve from 0.01444
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0023 - val_loss: 0.0276
# Epoch 25/50
# 4/4 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 00025: val_loss did not improve from 0.01444
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0029 - val_loss: 0.0239
# Epoch 26/50
# 4/4 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 00026: val_loss did not improve from 0.01444
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0022 - val_loss: 0.0170
# Epoch 27/50
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0015
# Epoch 00027: val_loss improved from 0.01444 to 0.01280, saving model to results/univariate_time_series/rnn.h5
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0019 - val_loss: 0.0128
# Epoch 28/50
# 4/4 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 00028: val_loss did not improve from 0.01280
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0020 - val_loss: 0.0134
# Epoch 29/50
# 4/4 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 00029: val_loss did not improve from 0.01280
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0020 - val_loss: 0.0207
# Epoch 30/50
# 4/4 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 00030: val_loss did not improve from 0.01280
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0020 - val_loss: 0.0202
# Epoch 31/50
# 4/4 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 00031: val_loss improved from 0.01280 to 0.01257, saving model to results/univariate_time_series/rnn.h5
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0019 - val_loss: 0.0126
# Epoch 32/50
# 4/4 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 00032: val_loss did not improve from 0.01257
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0020 - val_loss: 0.0135
# Epoch 33/50
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0023
# Epoch 00033: val_loss did not improve from 0.01257
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0021 - val_loss: 0.0148
# Epoch 34/50
# 3/4 [=====================>........] - ETA: 0s - loss: 0.0020
# Epoch 00034: val_loss did not improve from 0.01257
# 4/4 [==============================] - 0s 29ms/step - loss: 0.0019 - val_loss: 0.0127
# Epoch 35/50
# 4/4 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 00035: val_loss did not improve from 0.01257
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0019 - val_loss: 0.0181
# Epoch 36/50
# 4/4 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 00036: val_loss did not improve from 0.01257
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0019 - val_loss: 0.0151
# Epoch 37/50
# 4/4 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 00037: val_loss did not improve from 0.01257
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0018 - val_loss: 0.0179
# Epoch 38/50
# 4/4 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 00038: val_loss did not improve from 0.01257
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0021 - val_loss: 0.0141
# Epoch 39/50
# 3/4 [=====================>........] - ETA: 0s - loss: 0.0019
# Epoch 00039: val_loss improved from 0.01257 to 0.01074, saving model to results/univariate_time_series/rnn.h5
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0020 - val_loss: 0.0107
# Epoch 40/50
# 4/4 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 00040: val_loss did not improve from 0.01074
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0022 - val_loss: 0.0140
# Epoch 41/50
# 4/4 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 00041: val_loss did not improve from 0.01074
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0017 - val_loss: 0.0119
# Epoch 42/50
# 4/4 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 00042: val_loss did not improve from 0.01074
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0016 - val_loss: 0.0119
# Epoch 43/50
# 4/4 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 00043: val_loss did not improve from 0.01074
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0016 - val_loss: 0.0126
# Epoch 44/50
# 4/4 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 00044: val_loss did not improve from 0.01074
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0017 - val_loss: 0.0112
# Epoch 45/50
# 4/4 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 00045: val_loss did not improve from 0.01074
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0016 - val_loss: 0.0156
# Epoch 46/50
# 4/4 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 00046: val_loss improved from 0.01074 to 0.01067, saving model to results/univariate_time_series/rnn.h5
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0028 - val_loss: 0.0107
# Epoch 47/50
# 4/4 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 00047: val_loss improved from 0.01067 to 0.01060, saving model to results/univariate_time_series/rnn.h5
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0018 - val_loss: 0.0106
# Epoch 48/50
# 4/4 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 00048: val_loss did not improve from 0.01060
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0017 - val_loss: 0.0141
# Epoch 49/50
# 4/4 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 00049: val_loss did not improve from 0.01060
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0017 - val_loss: 0.0108
# Epoch 50/50
# 4/4 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 00050: val_loss did not improve from 0.01060
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0022 - val_loss: 0.0127

# %% [markdown]
# Training stops after 51 epochs; the `early_stopping` callback restores the weights for the best model (after 41 epochs)

# %% [markdown]
# ## Evaluate model performance

# %%
fig, ax = plt.subplots(figsize=(12, 4))

loss_history = pd.DataFrame(lstm_training.history).pow(.5)
loss_history.index += 1
best_rmse = loss_history.val_loss.min()

best_epoch = loss_history.val_loss.idxmin()

title = f'5-Epoch Rolling RMSE (Best Validation RMSE: {best_rmse:.4%})'
loss_history.columns=['Training RMSE', 'Validation RMSE']
loss_history.rolling(5).mean().plot(logy=True, lw=2, title=title, ax=ax)

ax.axvline(best_epoch, ls='--', lw=1, c='k')

sns.despine()
fig.tight_layout()
fig.savefig(results_path / 'rnn_sp500_error', dpi=300);

# %%
train_rmse_scaled = np.sqrt(rnn.evaluate(X_train, y_train, verbose=0))
test_rmse_scaled = np.sqrt(rnn.evaluate(X_test, y_test, verbose=0))
print(f'Train RMSE: {train_rmse_scaled:.4f} | Test RMSE: {test_rmse_scaled:.4f}')
# Out:
# Train RMSE: 0.0398 | Test RMSE: 0.1129

# %%
train_predict_scaled = rnn.predict(X_train)
test_predict_scaled = rnn.predict(X_test)

# %%
train_ic = spearmanr(y_train, train_predict_scaled)[0]
test_ic = spearmanr(y_test, test_predict_scaled)[0]
print(f'Train IC: {train_ic:.4f} | Test IC: {test_ic:.4f}')
# Out:
# Train IC: 0.9227 | Test IC: 0.7972

# %% [markdown]
# ### Rescale predictions

# %%
train_predict = pd.Series(scaler.inverse_transform(train_predict_scaled).squeeze(), index=y_train.index)
test_predict = (pd.Series(scaler.inverse_transform(test_predict_scaled).squeeze(), index=y_test.index))

# %%
y_train_rescaled = scaler.inverse_transform(y_train.to_frame()).squeeze()
y_test_rescaled = scaler.inverse_transform(y_test.to_frame()).squeeze()

# %%
train_rmse = np.sqrt(mean_squared_error(train_predict, y_train_rescaled))
test_rmse = np.sqrt(mean_squared_error(test_predict, y_test_rescaled))
f'Train RMSE: {train_rmse:.2f} | Test RMSE: {test_rmse:.2f}'
# Out:
# 'Train RMSE: 106.44 | Test RMSE: 301.62'

# %%
sp500['Train Predictions'] = train_predict
sp500['Test Predictions'] = test_predict
sp500 = sp500.join(train_predict.to_frame('predictions').assign(data='Train')
                        .append(test_predict.to_frame('predictions').assign(data='Test')))

# %% [markdown]
# ### Plot Results

# %%
fig=plt.figure(figsize=(14,7))
ax1 = plt.subplot(221)

sp500.loc['2015':, 'SP500'].plot(lw=4, ax=ax1, c='k')
sp500.loc['2015':, ['Test Predictions', 'Train Predictions']].plot(lw=1, ax=ax1, ls='--')
ax1.set_title('In- and Out-of-sample Predictions')


with sns.axes_style("white"):
    ax3 = plt.subplot(223)
    sns.scatterplot(x='SP500', y='predictions', data=sp500, hue='data', ax=ax3)
    ax3.text(x=.02, y=.95, s=f'Test IC ={test_ic:.2%}', transform=ax3.transAxes)
    ax3.text(x=.02, y=.87, s=f'Train IC={train_ic:.2%}', transform=ax3.transAxes)
    ax3.set_title('Correlation')
    ax3.legend(loc='lower right')
    
    ax2 = plt.subplot(222)
    ax4 = plt.subplot(224, sharex = ax2, sharey=ax2)
    sns.distplot(train_predict.squeeze()- y_train_rescaled, ax=ax2)
    ax2.set_title('Train Error')
    ax2.text(x=.03, y=.92, s=f'Train RMSE ={train_rmse:.4f}', transform=ax2.transAxes)
    sns.distplot(test_predict.squeeze()-y_test_rescaled, ax=ax4)
    ax4.set_title('Test Error')
    ax4.text(x=.03, y=.92, s=f'Test RMSE ={test_rmse:.4f}', transform=ax4.transAxes)

sns.despine()
fig.tight_layout()
fig.savefig(results_path / 'rnn_sp500_regression', dpi=300);
