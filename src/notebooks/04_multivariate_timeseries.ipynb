# %% [markdown]
# # Multivariate Time Series Regression

# %% [markdown]
# So far, we have limited our modeling efforts to single time series. RNNs are naturally well suited to multivariate time series and represent a non-linear alternative to the Vector Autoregressive (VAR) models we covered in Chapter 8, Time Series Models.

# %% [markdown]
# ## Imports & Settings

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %matplotlib inline

from pathlib import Path
import numpy as np
import pandas as pd
import pandas_datareader.data as web

from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import minmax_scale

import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, LSTM
import tensorflow.keras.backend as K

import matplotlib.pyplot as plt
import seaborn as sns

# %%
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
if gpu_devices:
    print('Using GPU')
    tf.config.experimental.set_memory_growth(gpu_devices[0], True)
else:
    print('Using CPU')
# Out:
# Using CPU

# %%
sns.set_style('whitegrid')
np.random.seed(42)

# %%
results_path = Path('results', 'multivariate_time_series')
if not results_path.exists():
    results_path.mkdir(parents=True)

# %% [markdown]
# ## Load Data

# %% [markdown]
# For comparison, we illustrate the application of RNNs to modeling and forecasting several time series using the same dataset we used for the VAR example, monthly data on consumer sentiment, and industrial production from the Federal Reserve's FRED service in Chapter 8, Time Series Models:

# %%
df = web.DataReader(['UMCSENT', 'IPGMFN'], 'fred', '1980', '2020-12').dropna()
df.columns = ['sentiment', 'ip']
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 491 entries, 1980-01-01 to 2020-11-01
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   sentiment  491 non-null    float64
#  1   ip         491 non-null    float64
# dtypes: float64(2)
# memory usage: 11.5 KB

# %%
df.head()
# Out:
#             sentiment       ip
# DATE
# 1980-01-01       67.0  46.8770
# 1980-02-01       66.9  47.9757
# 1980-03-01       56.5  48.4793
# 1980-04-01       52.7  47.0662
# 1980-05-01       51.7  45.6995

# %% [markdown]
# ## Prepare Data

# %% [markdown]
# ### Stationarity

# %% [markdown]
# We apply the same transformation—annual difference for both series, prior log-transform for industrial production—to achieve stationarity that we used in Chapter 8 on Time Series Models:

# %%
df_transformed = (pd.DataFrame({'ip': np.log(df.ip).diff(12),
                                'sentiment': df.sentiment.diff(12)})
                  .dropna())

# %% [markdown]
# ### Scaling

# %% [markdown]
# Then we scale the transformed data to the [0,1] interval:

# %%
df_transformed = df_transformed.apply(minmax_scale)

# %% [markdown]
# ### Plot original and transformed series

# %%
fig, axes = plt.subplots(ncols=2, figsize=(14,4))
columns={'ip': 'Industrial Production', 'sentiment': 'Sentiment'}
df.rename(columns=columns).plot(ax=axes[0], title='Original Series')
df_transformed.rename(columns=columns).plot(ax=axes[1], title='Tansformed Series')
sns.despine()
fig.tight_layout()
fig.savefig(results_path / 'multi_rnn', dpi=300);

# %% [markdown]
# ### Reshape data into RNN format

# %% [markdown]
# We can reshape directly to get non-overlapping series, i.e., one sample for each year (works only if the number of samples is divisible by window size):

# %%
df.values.reshape(-1, 12, 2).shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-6c48e1eb9d3a> in <module>
# ----> 1 df.values.reshape(-1, 12, 2).shape
#
# ValueError: cannot reshape array of size 982 into shape (12,2)

# %% [markdown]
# However, we want rolling, not non-overlapping lagged values. The create_multivariate_rnn_data function transforms a dataset of several time series into the shape required by the Keras RNN layers, namely `n_samples` x `window_size` x `n_series`, as follows:

# %%
def create_multivariate_rnn_data(data, window_size):
    y = data[window_size:]
    n = data.shape[0]
    X = np.stack([data[i: j] 
                  for i, j in enumerate(range(window_size, n))], axis=0)
    return X, y

# %% [markdown]
# We will use window_size of 24 months and obtain the desired inputs for our RNN model, as follows:

# %%
window_size = 18

# %%
X, y = create_multivariate_rnn_data(df_transformed, window_size=window_size)

# %%
X.shape, y.shape
# Out:
# ((450, 18, 2), (450, 2))

# %%
df_transformed.head()
# Out:
#                   ip  sentiment
# DATE
# 1981-01-01  0.526669   0.576214
# 1981-02-01  0.513795   0.502513
# 1981-03-01  0.542863   0.670017
# 1981-04-01  0.613397   0.832496
# 1981-05-01  0.731775   0.914573

# %% [markdown]
# Finally, we split our data into a train and a test set, using the last 24 months to test the out-of-sample performance, as shown here:

# %%
test_size =24
train_size = X.shape[0]-test_size

# %%
X_train, y_train = X[:train_size], y[:train_size]
X_test, y_test = X[train_size:], y[train_size:]

# %%
X_train.shape, X_test.shape
# Out:
# ((426, 18, 2), (24, 18, 2))

# %% [markdown]
# ## Define Model Architecture

# %% [markdown]
# We use a similar architecture with two stacked LSTM layers with 12 and 6 units, respectively, followed by a fully-connected layer with 10 units. The output layer has two units, one for each time series. We compile them using mean absolute loss and the recommended RMSProp optimizer, as follows:

# %%
K.clear_session()

# %%
n_features = output_size = 2

# %%
lstm_units = 12
dense_units = 6

# %%
rnn = Sequential([
    LSTM(units=lstm_units,
         dropout=.1,
         recurrent_dropout=.1,
         input_shape=(window_size, n_features), name='LSTM',
         return_sequences=False),
    Dense(dense_units, name='FC'),
    Dense(output_size, name='Output')
])

# %% [markdown]
# The model has 1,268 parameters, as shown here:

# %%
rnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM (LSTM)                  (None, 12)                720
# _________________________________________________________________
# FC (Dense)                   (None, 6)                 78
# _________________________________________________________________
# Output (Dense)               (None, 2)                 14
# =================================================================
# Total params: 812
# Trainable params: 812
# Non-trainable params: 0
# _________________________________________________________________

# %%
rnn.compile(loss='mae', optimizer='RMSProp')

# %% [markdown]
# ## Train the Model

# %% [markdown]
# We train for 50 epochs with a batch_size value of 20 using early stopping:

# %%
lstm_path = (results_path / 'lstm.h5').as_posix()

checkpointer = ModelCheckpoint(filepath=lstm_path,
                               verbose=1,
                               monitor='val_loss',
                               mode='min',
                               save_best_only=True)

# %%
early_stopping = EarlyStopping(monitor='val_loss', 
                              patience=10,
                              restore_best_weights=True)

# %%
result = rnn.fit(X_train,
                 y_train,
                 epochs=100,
                 batch_size=20,
                 shuffle=False,
                 validation_data=(X_test, y_test),
                 callbacks=[early_stopping, checkpointer],
                 verbose=1)
# Out:
# Epoch 1/100
# 20/22 [==========================>...] - ETA: 0s - loss: 0.2051
# Epoch 00001: val_loss improved from inf to 0.07308, saving model to results/multivariate_time_series/lstm.h5
# 22/22 [==============================] - 0s 22ms/step - loss: 0.1964 - val_loss: 0.0731
# Epoch 2/100
# 20/22 [==========================>...] - ETA: 0s - loss: 0.1154
# Epoch 00002: val_loss improved from 0.07308 to 0.05330, saving model to results/multivariate_time_series/lstm.h5
# 22/22 [==============================] - 0s 10ms/step - loss: 0.1121 - val_loss: 0.0533
# Epoch 3/100
# 19/22 [========================>.....] - ETA: 0s - loss: 0.1041
# Epoch 00003: val_loss improved from 0.05330 to 0.04408, saving model to results/multivariate_time_series/lstm.h5
# 22/22 [==============================] - 0s 10ms/step - loss: 0.1017 - val_loss: 0.0441
# Epoch 4/100
# 18/22 [=======================>......] - ETA: 0s - loss: 0.1024
# Epoch 00004: val_loss did not improve from 0.04408
# 22/22 [==============================] - 0s 10ms/step - loss: 0.1004 - val_loss: 0.0445
# Epoch 5/100
# 19/22 [========================>.....] - ETA: 0s - loss: 0.1019
# Epoch 00005: val_loss did not improve from 0.04408
# 22/22 [==============================] - 0s 10ms/step - loss: 0.1000 - val_loss: 0.0601
# Epoch 6/100
# 18/22 [=======================>......] - ETA: 0s - loss: 0.0966
# Epoch 00006: val_loss improved from 0.04408 to 0.04159, saving model to results/multivariate_time_series/lstm.h5
# 22/22 [==============================] - 0s 10ms/step - loss: 0.0958 - val_loss: 0.0416
# Epoch 7/100
# 18/22 [=======================>......] - ETA: 0s - loss: 0.0955
# Epoch 00007: val_loss improved from 0.04159 to 0.03874, saving model to results/multivariate_time_series/lstm.h5
# 22/22 [==============================] - 0s 11ms/step - loss: 0.0951 - val_loss: 0.0387
# Epoch 8/100
# 19/22 [========================>.....] - ETA: 0s - loss: 0.0940
# Epoch 00008: val_loss did not improve from 0.03874
# 22/22 [==============================] - 0s 9ms/step - loss: 0.0923 - val_loss: 0.0493
# Epoch 9/100
# 18/22 [=======================>......] - ETA: 0s - loss: 0.0924
# Epoch 00009: val_loss improved from 0.03874 to 0.03668, saving model to results/multivariate_time_series/lstm.h5
# 22/22 [==============================] - 0s 11ms/step - loss: 0.0921 - val_loss: 0.0367
# Epoch 10/100
# 18/22 [=======================>......] - ETA: 0s - loss: 0.0905
# Epoch 00010: val_loss did not improve from 0.03668
# 22/22 [==============================] - 0s 10ms/step - loss: 0.0903 - val_loss: 0.0368
# Epoch 11/100
# 19/22 [========================>.....] - ETA: 0s - loss: 0.0927
# Epoch 00011: val_loss did not improve from 0.03668
# 22/22 [==============================] - 0s 9ms/step - loss: 0.0914 - val_loss: 0.0482
# Epoch 12/100
# 19/22 [========================>.....] - ETA: 0s - loss: 0.0915
# Epoch 00012: val_loss did not improve from 0.03668
# 22/22 [==============================] - 0s 9ms/step - loss: 0.0902 - val_loss: 0.0414
# Epoch 13/100
# 19/22 [========================>.....] - ETA: 0s - loss: 0.0882
# Epoch 00013: val_loss did not improve from 0.03668
# 22/22 [==============================] - 0s 10ms/step - loss: 0.0870 - val_loss: 0.0417
# Epoch 14/100
# 18/22 [=======================>......] - ETA: 0s - loss: 0.0869
# Epoch 00014: val_loss did not improve from 0.03668
# 22/22 [==============================] - 0s 10ms/step - loss: 0.0868 - val_loss: 0.0412
# Epoch 15/100
# 19/22 [========================>.....] - ETA: 0s - loss: 0.0882
# Epoch 00015: val_loss improved from 0.03668 to 0.03667, saving model to results/multivariate_time_series/lstm.h5
# 22/22 [==============================] - 0s 10ms/step - loss: 0.0867 - val_loss: 0.0367
# Epoch 16/100
# 18/22 [=======================>......] - ETA: 0s - loss: 0.0859
# Epoch 00016: val_loss did not improve from 0.03667
# 22/22 [==============================] - 0s 10ms/step - loss: 0.0855 - val_loss: 0.0367
# Epoch 17/100
# 19/22 [========================>.....] - ETA: 0s - loss: 0.0845
# Epoch 00017: val_loss improved from 0.03667 to 0.03514, saving model to results/multivariate_time_series/lstm.h5
# 22/22 [==============================] - 0s 10ms/step - loss: 0.0834 - val_loss: 0.0351
# Epoch 18/100
# 18/22 [=======================>......] - ETA: 0s - loss: 0.0853
# Epoch 00018: val_loss did not improve from 0.03514
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0849 - val_loss: 0.0393
# Epoch 19/100
# 20/22 [==========================>...] - ETA: 0s - loss: 0.0843
# Epoch 00019: val_loss did not improve from 0.03514
# 22/22 [==============================] - 0s 9ms/step - loss: 0.0828 - val_loss: 0.0384
# Epoch 20/100
# 21/22 [===========================>..] - ETA: 0s - loss: 0.0827
# Epoch 00020: val_loss did not improve from 0.03514
# 22/22 [==============================] - 0s 11ms/step - loss: 0.0825 - val_loss: 0.0382
# Epoch 21/100
# 21/22 [===========================>..] - ETA: 0s - loss: 0.0815
# Epoch 00021: val_loss did not improve from 0.03514
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0813 - val_loss: 0.0405
# Epoch 22/100
# 18/22 [=======================>......] - ETA: 0s - loss: 0.0792
# Epoch 00022: val_loss did not improve from 0.03514
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0792 - val_loss: 0.0373
# Epoch 23/100
# 21/22 [===========================>..] - ETA: 0s - loss: 0.0807
# Epoch 00023: val_loss did not improve from 0.03514
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0803 - val_loss: 0.0352
# Epoch 24/100
# 20/22 [==========================>...] - ETA: 0s - loss: 0.0833
# Epoch 00024: val_loss did not improve from 0.03514
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0817 - val_loss: 0.0373
# Epoch 25/100
# 20/22 [==========================>...] - ETA: 0s - loss: 0.0828
# Epoch 00025: val_loss did not improve from 0.03514
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0809 - val_loss: 0.0368
# Epoch 26/100
# 19/22 [========================>.....] - ETA: 0s - loss: 0.0843
# Epoch 00026: val_loss did not improve from 0.03514
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0821 - val_loss: 0.0355
# Epoch 27/100
# 22/22 [==============================] - ETA: 0s - loss: 0.0809
# Epoch 00027: val_loss improved from 0.03514 to 0.03496, saving model to results/multivariate_time_series/lstm.h5
# 22/22 [==============================] - 0s 9ms/step - loss: 0.0809 - val_loss: 0.0350
# Epoch 28/100
# 20/22 [==========================>...] - ETA: 0s - loss: 0.0811
# Epoch 00028: val_loss did not improve from 0.03496
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0797 - val_loss: 0.0365
# Epoch 29/100
# 22/22 [==============================] - ETA: 0s - loss: 0.0780
# Epoch 00029: val_loss did not improve from 0.03496
# 22/22 [==============================] - 0s 11ms/step - loss: 0.0780 - val_loss: 0.0350
# Epoch 30/100
# 18/22 [=======================>......] - ETA: 0s - loss: 0.0787
# Epoch 00030: val_loss did not improve from 0.03496
# 22/22 [==============================] - 0s 10ms/step - loss: 0.0783 - val_loss: 0.0363
# Epoch 31/100
# 17/22 [======================>.......] - ETA: 0s - loss: 0.0815
# Epoch 00031: val_loss did not improve from 0.03496
# 22/22 [==============================] - 0s 10ms/step - loss: 0.0788 - val_loss: 0.0358
# Epoch 32/100
# 20/22 [==========================>...] - ETA: 0s - loss: 0.0809
# Epoch 00032: val_loss improved from 0.03496 to 0.03438, saving model to results/multivariate_time_series/lstm.h5
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0792 - val_loss: 0.0344
# Epoch 33/100
# 20/22 [==========================>...] - ETA: 0s - loss: 0.0794
# Epoch 00033: val_loss did not improve from 0.03438
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0789 - val_loss: 0.0374
# Epoch 34/100
# 20/22 [==========================>...] - ETA: 0s - loss: 0.0805
# Epoch 00034: val_loss did not improve from 0.03438
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0786 - val_loss: 0.0365
# Epoch 35/100
# 18/22 [=======================>......] - ETA: 0s - loss: 0.0764
# Epoch 00035: val_loss did not improve from 0.03438
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0761 - val_loss: 0.0349
# Epoch 36/100
# 22/22 [==============================] - ETA: 0s - loss: 0.0792
# Epoch 00036: val_loss did not improve from 0.03438
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0792 - val_loss: 0.0385
# Epoch 37/100
# 17/22 [======================>.......] - ETA: 0s - loss: 0.0773
# Epoch 00037: val_loss did not improve from 0.03438
# 22/22 [==============================] - 0s 10ms/step - loss: 0.0751 - val_loss: 0.0392
# Epoch 38/100
# 21/22 [===========================>..] - ETA: 0s - loss: 0.0758
# Epoch 00038: val_loss did not improve from 0.03438
# 22/22 [==============================] - 0s 9ms/step - loss: 0.0755 - val_loss: 0.0368
# Epoch 39/100
# 18/22 [=======================>......] - ETA: 0s - loss: 0.0760
# Epoch 00039: val_loss did not improve from 0.03438
# 22/22 [==============================] - 0s 10ms/step - loss: 0.0761 - val_loss: 0.0352
# Epoch 40/100
# 21/22 [===========================>..] - ETA: 0s - loss: 0.0767
# Epoch 00040: val_loss did not improve from 0.03438
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0764 - val_loss: 0.0359
# Epoch 41/100
# 17/22 [======================>.......] - ETA: 0s - loss: 0.0788
# Epoch 00041: val_loss did not improve from 0.03438
# 22/22 [==============================] - 0s 10ms/step - loss: 0.0775 - val_loss: 0.0451
# Epoch 42/100
# 17/22 [======================>.......] - ETA: 0s - loss: 0.0793
# Epoch 00042: val_loss did not improve from 0.03438
# 22/22 [==============================] - 0s 11ms/step - loss: 0.0774 - val_loss: 0.0346

# %% [markdown]
# ## Evaluate the Results

# %% [markdown]
# Training stops early after 22 epochs, yielding a test MAE of 1.71, which compares favorably to the test MAE for the VAR model of 1.91.

# %% [markdown]
# However, the two results are not fully comparable because the RNN model produces 24 one-step-ahead forecasts, whereas the VAR model uses its own predictions as input for its out-of-sample forecast. You may want to tweak the VAR setup to obtain comparable forecasts and compare their performance:

# %%
pd.DataFrame(result.history).plot();

# %%
y_pred = pd.DataFrame(rnn.predict(X_test), 
                      columns=y_test.columns, 
                      index=y_test.index)
y_pred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 24 entries, 2018-01-01 to 2019-12-01
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ip         24 non-null     float32
#  1   sentiment  24 non-null     float32
# dtypes: float32(2)
# memory usage: 384.0 bytes

# %%
test_mae = mean_absolute_error(y_pred, y_test)

# %%
print(test_mae)
# Out:
# 0.03438069310997868

# %%
y_test.index
# Out:
# DatetimeIndex(['2018-01-01', '2018-02-01', '2018-03-01', '2018-04-01',
#                '2018-05-01', '2018-06-01', '2018-07-01', '2018-08-01',
#                '2018-09-01', '2018-10-01', '2018-11-01', '2018-12-01',
#                '2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01',
#                '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01',
#                '2019-09-01', '2019-10-01', '2019-11-01', '2019-12-01'],
#               dtype='datetime64[ns]', name='DATE', freq=None)

# %%
fig, axes = plt.subplots(ncols=3, figsize=(17, 4))
pd.DataFrame(result.history).rename(columns={'loss': 'Training',
                                              'val_loss': 'Validation'}).plot(ax=axes[0], title='Train & Validiation Error')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('MAE')
col_dict = {'ip': 'Industrial Production', 'sentiment': 'Sentiment'}

for i, col in enumerate(y_test.columns, 1):
    y_train.loc['2010':, col].plot(ax=axes[i], label='training', title=col_dict[col])
    y_test[col].plot(ax=axes[i], label='out-of-sample')
    y_pred[col].plot(ax=axes[i], label='prediction')
    axes[i].set_xlabel('')

axes[1].set_ylim(.5, .9)
axes[1].fill_between(x=y_test.index, y1=0.5, y2=0.9, color='grey', alpha=.5)

axes[2].set_ylim(.3, .9)
axes[2].fill_between(x=y_test.index, y1=0.3, y2=0.9, color='grey', alpha=.5)

plt.legend()
fig.suptitle('Multivariate RNN - Results | Test MAE = {:.4f}'.format(test_mae), fontsize=14)
sns.despine()
fig.tight_layout()
fig.subplots_adjust(top=.85)
fig.savefig(results_path / 'multivariate_results', dpi=300);
